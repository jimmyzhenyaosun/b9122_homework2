# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
#from urllib.request import Request

# %%
seed_url = "https://press.un.org/en"

urls = [seed_url]    #queue of urls to crawl
seen = [seed_url]    #stack of urls seen so far
opened = []          #we keep track of seen urls so that we don't revisit them
crisis_related = []

# %%
maxNumUrl = 500; #set the maximum number of urls to visit
print("Starting with url="+str(urls))
while len(urls) > 0 and len(opened) < maxNumUrl and len(crisis_related) < 10:
    try:
        curr_url = urls.pop(0)
        print("num. of URLs in stack: %d " % len(urls))
        print("Trying to access= "+curr_url)
        req = urllib.request.Request(curr_url,headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urllib.request.urlopen(req).read()
        opened.append(curr_url)
    except Exception as ex:
        print("Unable to access= "+curr_url)
        print(ex)
        continue
    
    #Part 1: check curr_url and see if it is a crisis_related press release
    soup = BeautifulSoup(webpage)
    text = soup.get_text().lower().replace('-',' ').replace(',',' ').replace('.',' ').replace('\n',' ').split()
    find=[]
    for tag in soup.find_all('a', href="/en/press-release", hreflang="en"):
        find.append(tag['href'])
    if 'crisis' in text and len(find)>0:
        crisis_related.append(curr_url)
    print("num of crisis urls: %d" % len(crisis_related))
    
    #Part2: keep crawling and saving all children href into url if they are new and consistent with seed
    for tag in soup.find_all('a', href= True): #find tags with links
        childUrl = tag['href'] #extract just the link
        childUrl = urllib.parse.urljoin(seed_url, childUrl)
        
        #check if childurl are consistent with 'https://press.un.org' which is the seed url
        dot_position = seed_url.rfind('.')
        if seed_url[0:dot_position] in childUrl and childUrl not in seen:
            urls.append(childUrl)
            seen.append(childUrl)

print("num. of URLs seen = %d, and scanned = %d" % (len(seen), len(opened)))
#the crawling process is around 4min
# Out:
# Starting with url=['https://press.un.org/en']
# num. of URLs in stack: 0
# Trying to access= https://press.un.org/en
# num of crisis urls: 0
# num. of URLs in stack: 46
# Trying to access= https://press.un.org/en#main-content
# num of crisis urls: 0
# num. of URLs in stack: 45
# Trying to access= https://press.un.org/fr/home
# num of crisis urls: 0
# num. of URLs in stack: 95
# Trying to access= https://press.un.org/en/content/secretary-general
# num of crisis urls: 0
# num. of URLs in stack: 111
# Trying to access= https://press.un.org/en/content/secretary-general/press-release
# num of crisis urls: 0
# num. of URLs in stack: 112
# Trying to access= https://press.un.org/en/content/secretary-general/press-conference
# num of crisis urls: 0
# num. of URLs in stack: 122
# Trying to access= https://press.un.org/en/content/general-assembly
# num of crisis urls: 0
# num. of URLs in stack: 137
# Trying to access= https://press.un.org/en/content/general-assembly/meetings-coverage
# num of crisis urls: 0
# num. of URLs in stack: 138
# Trying to access= https://press.un.org/en/content/general-assembly/press-release
# num of crisis urls: 0
# num. of URLs in stack: 147
# Trying to access= https://press.un.org/en/content/security-council
# num of crisis urls: 0
# num. of URLs in stack: 155
# Trying to access= https://press.un.org/en/content/security-council/meetings-coverage
# num of crisis urls: 0
# num. of URLs in stack: 160
# Trying to access= https://press.un.org/en/content/security-council/press-release
# num of crisis urls: 0
# num. of URLs in stack: 166
# Trying to access= https://press.un.org/en/content/security-council/press-conference
# num of crisis urls: 0
# num. of URLs in stack: 175
# Trying to access= https://press.un.org/en/content/economic-and-social-council
# num of crisis urls: 0
# num. of URLs in stack: 192
# Trying to access= https://press.un.org/en/content/economic-and-social-council/meetings-coverage
# num of crisis urls: 0
# num. of URLs in stack: 195
# Trying to access= https://press.un.org/en/content/economic-and-social-council/press-release
# num of crisis urls: 0
# num. of URLs in stack: 202
# Trying to access= https://press.un.org/en/about
# num of crisis urls: 0
# num. of URLs in stack: 201
# Trying to access= https://press.un.org/en/2023/gal3688.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 206
# Trying to access= https://press.un.org/en/2023/gashc4376.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 209
# Trying to access= https://press.un.org/en/2023/gaef3585.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 212
# Trying to access= https://press.un.org/en/2023/gal3687.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 217
# Trying to access= https://press.un.org/en/2023/gaspd777.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 220
# Trying to access= https://press.un.org/en/2023/gadis3711.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 223
# Trying to access= https://press.un.org/en/2023/gaab4427.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 226
# Trying to access= https://press.un.org/en/2023/gaef3584.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 229
# Trying to access= https://press.un.org/en/content/meetings-coverage
# num of crisis urls: 0
# num. of URLs in stack: 229
# Trying to access= https://press.un.org/en/2023/sc15433.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 235
# Trying to access= https://press.un.org/en/2023/sgsm21974.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 240
# Trying to access= https://press.un.org/en/2023/sg2264.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 245
# Trying to access= https://press.un.org/en/2023/sgsm21973.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 248
# Trying to access= https://press.un.org/en/2023/sgsm21972.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 254
# Trying to access= https://press.un.org/en/2023/sea2186.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 258
# Trying to access= https://press.un.org/en/2023/sgsm21971.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 262
# Trying to access= https://press.un.org/en/2023/sgsm21970.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 266
# Trying to access= https://press.un.org/en/2023/sgsm21968.doc.htm
# num of crisis urls: 0
# num. of URLs in stack: 270
# Trying to access= https://press.un.org/en/2023/sgsm21967.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 274
# Trying to access= https://press.un.org/en/content/press-release
# num of crisis urls: 1
# num. of URLs in stack: 274
# Trying to access= https://press.un.org/en/2023/ga12487.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 278
# Trying to access= https://press.un.org/en/highlights/UNGA78
# num of crisis urls: 1
# num. of URLs in stack: 284
# Trying to access= https://press.un.org/en/2023/sc15172.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 619
# Trying to access= https://press.un.org/en/highlights/WaterAction
# num of crisis urls: 1
# num. of URLs in stack: 629
# Trying to access= https://press.un.org/en/highlights/CSW67
# num of crisis urls: 1
# num. of URLs in stack: 646
# Trying to access= https://press.un.org/en/highlights/LDC5
# num of crisis urls: 1
# num. of URLs in stack: 670
# Trying to access= https://press.un.org/en/2023/db231005.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 688
# Trying to access= https://press.un.org/en/content/noon-briefings
# num of crisis urls: 1
# num. of URLs in stack: 697
# Trying to access= https://press.un.org/en/2023/231002_sc.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 701
# Trying to access= https://press.un.org/en/content/press-conference
# num of crisis urls: 1
# num. of URLs in stack: 701
# Trying to access= https://press.un.org/en/rss.xml
# C:\Users\jimmy\anaconda3\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# num of crisis urls: 1
# num. of URLs in stack: 700
# Trying to access= https://press.un.org/fr
# num of crisis urls: 1
# num. of URLs in stack: 699
# Trying to access= https://press.un.org/en/home
# num of crisis urls: 1
# num. of URLs in stack: 698
# Trying to access= https://press.un.org/fr/content/secretary-general
# num of crisis urls: 1
# num. of URLs in stack: 705
# Trying to access= https://press.un.org/fr/content/statements-and-messages
# num of crisis urls: 1
# num. of URLs in stack: 708
# Trying to access= https://press.un.org/fr/content/secretary-general/press-conference
# num of crisis urls: 1
# num. of URLs in stack: 717
# Trying to access= https://press.un.org/fr/content/general-assembly
# num of crisis urls: 1
# num. of URLs in stack: 731
# Trying to access= https://press.un.org/fr/content/general-assembly/meetings-coverage
# num of crisis urls: 1
# num. of URLs in stack: 731
# Trying to access= https://press.un.org/fr/content/general-assembly/press-release
# num of crisis urls: 1
# num. of URLs in stack: 741
# Trying to access= https://press.un.org/fr/content/security-council
# num of crisis urls: 1
# num. of URLs in stack: 749
# Trying to access= https://press.un.org/fr/content/security-council/meetings-coverage
# num of crisis urls: 1
# num. of URLs in stack: 754
# Trying to access= https://press.un.org/fr/content/security-council/press-release
# num of crisis urls: 1
# num. of URLs in stack: 760
# Trying to access= https://press.un.org/fr/content/security-council/press-conference
# num of crisis urls: 1
# num. of URLs in stack: 769
# Trying to access= https://press.un.org/fr/content/economic-and-social-council
# num of crisis urls: 1
# num. of URLs in stack: 786
# Trying to access= https://press.un.org/fr/content/economic-and-social-council/meetings-coverage
# num of crisis urls: 1
# num. of URLs in stack: 787
# Trying to access= https://press.un.org/fr/content/economic-and-social-council/press-release
# num of crisis urls: 1
# num. of URLs in stack: 796
# Trying to access= https://press.un.org/fr/content/economic-and-social-council/press-conference
# num of crisis urls: 1
# num. of URLs in stack: 806
# Trying to access= https://press.un.org/fr/about
# num of crisis urls: 1
# num. of URLs in stack: 805
# Trying to access= https://press.un.org/fr/2023/agj3688.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 810
# Trying to access= https://press.un.org/fr/2023/ag12542.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 813
# Trying to access= https://press.un.org/fr/2023/agab4427.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 816
# Trying to access= https://press.un.org/fr/2023/cpsd777.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 819
# Trying to access= https://press.un.org/fr/2023/agj3687.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 822
# Trying to access= https://press.un.org/fr/2023/agshc4376.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 825
# Trying to access= https://press.un.org/fr/2023/agef3585.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 828
# Trying to access= https://press.un.org/fr/2023/agdsi3711.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 831
# Trying to access= https://press.un.org/fr/content/meetings-coverage
# num of crisis urls: 1
# num. of URLs in stack: 831
# Trying to access= https://press.un.org/fr/2023/sg2264.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 838
# Trying to access= https://press.un.org/fr/2023/sc15433.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 843
# Trying to access= https://press.un.org/fr/2023/sgsm21974.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 847
# Trying to access= https://press.un.org/fr/2023/sgsm21973.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 850
# Trying to access= https://press.un.org/fr/2023/mer2186.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 855
# Trying to access= https://press.un.org/fr/2023/sgsm21971.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 859
# Trying to access= https://press.un.org/fr/2023/sgsm21970.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 863
# Trying to access= https://press.un.org/fr/2023/sgsm21969.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 867
# Trying to access= https://press.un.org/fr/2023/sga2231.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 872
# Trying to access= https://press.un.org/fr/2023/sgsm21968.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 875
# Trying to access= https://press.un.org/fr/content/press-release
# num of crisis urls: 1
# num. of URLs in stack: 875
# Trying to access= https://press.un.org/fr/2023/agdsi3712.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 878
# Trying to access= https://press.un.org/fr/2023/agef3586.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 881
# Trying to access= https://press.un.org/fr/2023/agshc4377.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 884
# Trying to access= https://press.un.org/fr/2023/cs15172.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1114
# Trying to access= https://press.un.org/fr/highlights/WaterAction
# num of crisis urls: 1
# num. of URLs in stack: 1123
# Trying to access= https://press.un.org/fr/highlights/CSW67
# num of crisis urls: 1
# num. of URLs in stack: 1134
# Trying to access= https://press.un.org/fr/highlights/LDC5
# num of crisis urls: 1
# num. of URLs in stack: 1156
# Trying to access= https://press.un.org/fr/2023/ag12487.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1188
# Trying to access= https://press.un.org/fr/highlights/UNGA78
# num of crisis urls: 1
# num. of URLs in stack: 1193
# Trying to access= https://press.un.org/fr/2023/dbf231005.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1203
# Trying to access= https://press.un.org/fr/content/noon-briefings
# num of crisis urls: 1
# num. of URLs in stack: 1212
# Trying to access= https://press.un.org/fr/2023/conf231002cs.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1216
# Trying to access= https://press.un.org/fr/content/press-conference
# num of crisis urls: 1
# num. of URLs in stack: 1216
# Trying to access= https://press.un.org/fr/rss.xml
# num of crisis urls: 1
# num. of URLs in stack: 1215
# Trying to access= https://press.un.org/en/2023/sgsm21969.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1219
# Trying to access= https://press.un.org/en/2023/sga2231.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=0
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=1
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=2
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=3
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=4
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=5
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=6
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=7
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=8
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en?page=1937
# num of crisis urls: 1
# num. of URLs in stack: 1224
# Trying to access= https://press.un.org/en/statements-and-messages
# num of crisis urls: 1
# num. of URLs in stack: 1226
# Trying to access= https://press.un.org/en/appointments
# num of crisis urls: 1
# num. of URLs in stack: 1235
# Trying to access= https://press.un.org/en/travel
# num of crisis urls: 1
# num. of URLs in stack: 1245
# Trying to access= https://press.un.org/en/miscellaneous
# num of crisis urls: 1
# num. of URLs in stack: 1253
# Trying to access= https://press.un.org/en/deputy-secretary-general
# num of crisis urls: 1
# num. of URLs in stack: 1262
# Trying to access= https://press.un.org/fr/content/secretary-general/press-release
# num of crisis urls: 1
# num. of URLs in stack: 1262
# Trying to access= https://press.un.org/en?page=1927
# num of crisis urls: 1
# num. of URLs in stack: 1262
# Trying to access= https://press.un.org/en/2023/sgsm21938.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1265
# Trying to access= https://press.un.org/en/2023/sgsm21893.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1269
# Trying to access= https://press.un.org/en/2023/sgsm21840.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1272
# Trying to access= https://press.un.org/en/2023/sgsm21832.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1275
# Trying to access= https://press.un.org/en/2022/sgsm21640.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1278
# Trying to access= https://press.un.org/en/2022/sgsm21454.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1281
# Trying to access= https://press.un.org/en/2022/sgsm21397.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1284
# Trying to access= https://press.un.org/en/2022/sgsm21315.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1288
# Trying to access= https://press.un.org/en/2022/sgsm21236.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1292
# Trying to access= https://press.un.org/en/2022/sgsm21115.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1295
# Trying to access= https://press.un.org/en?page=9
# num of crisis urls: 1
# num. of URLs in stack: 1295
# Trying to access= https://press.un.org/en/2023/gal3686.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1298
# Trying to access= https://press.un.org/en?page=982
# num of crisis urls: 1
# num. of URLs in stack: 1298
# Trying to access= https://press.un.org/en/general-assembly-plenary
# num of crisis urls: 1
# num. of URLs in stack: 1302
# Trying to access= https://press.un.org/en/first-committee
# num of crisis urls: 1
# num. of URLs in stack: 1310
# Trying to access= https://press.un.org/en/second-committee
# num of crisis urls: 1
# num. of URLs in stack: 1317
# Trying to access= https://press.un.org/en/third-committee
# num of crisis urls: 1
# num. of URLs in stack: 1324
# Trying to access= https://press.un.org/en/fourth-committee
# num of crisis urls: 1
# num. of URLs in stack: 1332
# Trying to access= https://press.un.org/en/fifth-committee
# num of crisis urls: 1
# num. of URLs in stack: 1340
# Trying to access= https://press.un.org/en/sixth-committee
# num of crisis urls: 1
# num. of URLs in stack: 1346
# Trying to access= https://press.un.org/en/peacebuilding-commission
# num of crisis urls: 1
# num. of URLs in stack: 1355
# Trying to access= https://press.un.org/en/disarmament-commission
# num of crisis urls: 1
# num. of URLs in stack: 1364
# Trying to access= https://press.un.org/en/committee-inalienable-rights-palestinian-people
# num of crisis urls: 1
# num. of URLs in stack: 1374
# Trying to access= https://press.un.org/en/committee-information
# num of crisis urls: 1
# num. of URLs in stack: 1383
# Trying to access= https://press.un.org/en/special-committee-decolonization
# num of crisis urls: 1
# num. of URLs in stack: 1393
# Trying to access= https://press.un.org/en/special-committee-peacekeeping-operations
# num of crisis urls: 1
# num. of URLs in stack: 1402
# Trying to access= https://press.un.org/en/special-committee-united-nations-charter
# num of crisis urls: 1
# num. of URLs in stack: 1411
# Trying to access= https://press.un.org/en/2023/gashc4375.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1414
# Trying to access= https://press.un.org/en?page=429
# num of crisis urls: 1
# num. of URLs in stack: 1414
# Trying to access= https://press.un.org/en/2023/gal3684.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1419
# Trying to access= https://press.un.org/en/2023/gaab4424.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1423
# Trying to access= https://press.un.org/en/2023/gaspd773.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1427
# Trying to access= https://press.un.org/en/2023/gashc4371.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1431
# Trying to access= https://press.un.org/en/2023/gaef3581.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1435
# Trying to access= https://press.un.org/en/2023/gadis3707.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1439
# Trying to access= https://press.un.org/en/2023/sgsm21960.doc.htm
# num of crisis urls: 1
# num. of URLs in stack: 1443
# Trying to access= https://press.un.org/en/2023/sgsm21947.doc.htm
# num of crisis urls: 2
# num. of URLs in stack: 1446
# Trying to access= https://press.un.org/en/2023/dsgsm1874.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1451
# Trying to access= https://press.un.org/en?page=542
# num of crisis urls: 3
# num. of URLs in stack: 1451
# Trying to access= https://press.un.org/en/2023/sc15432.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1455
# Trying to access= https://press.un.org/en/2023/sc15431.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1459
# Trying to access= https://press.un.org/en/2023/sc15430.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1463
# Trying to access= https://press.un.org/en/2023/sc15429.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1467
# Trying to access= https://press.un.org/en/2023/sc15428.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1470
# Trying to access= https://press.un.org/en/2023/sc15427.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1473
# Trying to access= https://press.un.org/en/2023/sc15426.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1477
# Trying to access= https://press.un.org/en/2023/sc15425.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1481
# Trying to access= https://press.un.org/en?page=907
# num of crisis urls: 3
# num. of URLs in stack: 1481
# Trying to access= https://press.un.org/en/2023/sc15424.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1488
# Trying to access= https://press.un.org/en/2023/sc15422.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1492
# Trying to access= https://press.un.org/en/2023/sc15421.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1496
# Trying to access= https://press.un.org/en/2023/sc15420.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1500
# Trying to access= https://press.un.org/en/2023/sc15418.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1504
# Trying to access= https://press.un.org/en?page=306
# num of crisis urls: 3
# num. of URLs in stack: 1504
# Trying to access= https://press.un.org/en/2023/sc15423.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1507
# Trying to access= https://press.un.org/en/2023/sc15419.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1510
# Trying to access= https://press.un.org/en/2023/sc15417.doc.htm
# num of crisis urls: 3
# num. of URLs in stack: 1513
# Trying to access= https://press.un.org/en/2023/sgsm21952.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1516
# Trying to access= https://press.un.org/en/2023/sc15415.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1519
# Trying to access= https://press.un.org/en/2023/sc15413.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1522
# Trying to access= https://press.un.org/en?page=580
# num of crisis urls: 4
# num. of URLs in stack: 1522
# Trying to access= https://press.un.org/en/2023/230901_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1525
# Trying to access= https://press.un.org/en/2023/230801_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1528
# Trying to access= https://press.un.org/en/2023/230703_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1531
# Trying to access= https://press.un.org/en/2023/230601sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1534
# Trying to access= https://press.un.org/en/2023/230501_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1537
# Trying to access= https://press.un.org/en/2023/230403_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1540
# Trying to access= https://press.un.org/en/2023/230301_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1543
# Trying to access= https://press.un.org/en/2023/230201_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1546
# Trying to access= https://press.un.org/en/2023/230103_sc.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1549
# Trying to access= https://press.un.org/en?page=19
# num of crisis urls: 4
# num. of URLs in stack: 1549
# Trying to access= https://press.un.org/en/2023/ecosoc/7145.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1553
# Trying to access= https://press.un.org/en/2023/ecosoc7144.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1557
# Trying to access= https://press.un.org/en/2023/ecosoc7143.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1561
# Trying to access= https://press.un.org/en/2023/dsgsm1860.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1564
# Trying to access= https://press.un.org/en/2023/ecosoc7142.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1567
# Trying to access= https://press.un.org/en/2023/ecosoc7141.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1570
# Trying to access= https://press.un.org/en/2023/sgsm21882.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1573
# Trying to access= https://press.un.org/en/2023/ecosoc7140.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1576
# Trying to access= https://press.un.org/en/2023/ecosoc7139.doc.htm
# num of crisis urls: 4
# num. of URLs in stack: 1579
# Trying to access= https://press.un.org/en/2023/sgsm21876.doc.htm
# num of crisis urls: 5
# num. of URLs in stack: 1582
# Trying to access= https://press.un.org/en?page=202
# num of crisis urls: 5
# num. of URLs in stack: 1582
# Trying to access= https://press.un.org/en/ECOSOC-plenary
# num of crisis urls: 5
# num. of URLs in stack: 1585
# Trying to access= https://press.un.org/en/commission-social-development
# num of crisis urls: 5
# num. of URLs in stack: 1594
# Trying to access= https://press.un.org/en/commission-population-and-development
# num of crisis urls: 5
# num. of URLs in stack: 1603
# Trying to access= https://press.un.org/en/commission-status-women
# num of crisis urls: 5
# num. of URLs in stack: 1602
# Trying to access= https://press.un.org/en/committee-non-governmental-organizations
# num of crisis urls: 5
# num. of URLs in stack: 1612
# Trying to access= https://press.un.org/en/permanent-forum-indigenous-issues
# num of crisis urls: 5
# num. of URLs in stack: 1620
# Trying to access= https://press.un.org/en/united-nations-forum-forests
# num of crisis urls: 5
# num. of URLs in stack: 1629
# Trying to access= https://press.un.org/en/2023/ecosoc7138.doc.htm
# num of crisis urls: 5
# num. of URLs in stack: 1632
# Trying to access= https://press.un.org/en/2023/ecosoc7137.doc.htm
# num of crisis urls: 5
# num. of URLs in stack: 1635
# Trying to access= https://press.un.org/en/2023/ecosoc7136.doc.htm
# num of crisis urls: 5
# num. of URLs in stack: 1638
# Trying to access= https://press.un.org/en?page=113
# num of crisis urls: 5
# num. of URLs in stack: 1638
# Trying to access= https://press.un.org/en/2023/sgsm21852.doc.htm
# num of crisis urls: 6
# num. of URLs in stack: 1641
# Trying to access= https://press.un.org/en/2023/dsgsm1854.doc.htm
# num of crisis urls: 6
# num. of URLs in stack: 1644
# Trying to access= https://press.un.org/en/2023/sgsm21806.doc.htm
# num of crisis urls: 7
# num. of URLs in stack: 1647
# Trying to access= https://press.un.org/en/2023/dsgsm1848.doc.htm
# num of crisis urls: 8
# num. of URLs in stack: 1650
# Trying to access= https://press.un.org/en/2023/sgsm21774.doc.htm
# num of crisis urls: 8
# num. of URLs in stack: 1653
# Trying to access= https://press.un.org/en/2023/sgsm21765.doc.htm
# num of crisis urls: 9
# num. of URLs in stack: 1656
# Trying to access= https://press.un.org/en/2023/sgsm21767.doc.htm
# num of crisis urls: 10
# num. of URLs seen = 1878, and scanned = 218

# %%
print("List of URLs that contains crisis:")
for url in crisis_related:
    print(url)
# Out:
# List of URLs that contains crisis:
# https://press.un.org/en/2023/sgsm21967.doc.htm
# https://press.un.org/en/2023/sgsm21947.doc.htm
# https://press.un.org/en/2023/dsgsm1874.doc.htm
# https://press.un.org/en/2023/sgsm21952.doc.htm
# https://press.un.org/en/2023/sgsm21876.doc.htm
# https://press.un.org/en/2023/sgsm21852.doc.htm
# https://press.un.org/en/2023/sgsm21806.doc.htm
# https://press.un.org/en/2023/dsgsm1848.doc.htm
# https://press.un.org/en/2023/sgsm21765.doc.htm
# https://press.un.org/en/2023/sgsm21767.doc.htm

# %%
part=1
num=1 #num of url
for url in crisis_related:
    res = requests.get(url)
    html_content = res.text
    f = open("{}_{}.txt".format(part,num), "w", encoding= 'utf-8')
    f.write(html_content)
    f.close()
    print("HTML content for Question {}, article {} is saved.".format(part,num))
    num+=1
# Out:
# HTML content for Question 1, article 1 is saved.
# HTML content for Question 1, article 2 is saved.
# HTML content for Question 1, article 3 is saved.
# HTML content for Question 1, article 4 is saved.
# HTML content for Question 1, article 5 is saved.
# HTML content for Question 1, article 6 is saved.
# HTML content for Question 1, article 7 is saved.
# HTML content for Question 1, article 8 is saved.
# HTML content for Question 1, article 9 is saved.
# HTML content for Question 1, article 10 is saved.
